# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *

def first_population(entered_num):

    empty_list = []

    for x in range(entered_num):


        lifeSpan = randrange(18,99)
        birthRate = randint(1, 4)
        Occupation = choice(['Manual Labor', 'Militia', 'Medical Aid', 'Agricultural', 'GovWarlord', 'Tech'])

        num = 1 + x   
        df = 1 + x

        name = 'list' + str(num)
        name = [birthRate, Occupation, lifeSpan]

        empty_list.append(name)


    df = pd.DataFrame(empty_list, columns =['Birth Rate', 'Occupation', 'Life Span'])
    
    df.to_csv("/home/aaron/file_pop.csv")

    return(df)
    return(entered_num)

first_population(999)

df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

df1.info(verbose=True)

a = df['Occupation'].str.split('|', expand=True).stack().value_counts()

def plot_occupation():

    import matplotlib.pyplot as plt


    sales_by_type = df1["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')

    for index_label, row_series in df1.iterrows():
    # For each row update the 'Bonus' value to it's double
        df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
        
    df1

#print(type(a))

#df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 3 columns):
# Birth Rate    999 non-null int64
# Occupation    999 non-null object
# Life Span     999 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 23.5+ KB

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *

def first_population(entered_num):

    empty_list = []

    for x in range(entered_num):


        lifeSpan = randrange(18,99)
        birthRate = randint(1, 4)
        Occupation = choice(['Manual Labor', 'Militia', 'Medical Aid', 'Agricultural', 'GovWarlord', 'Tech'])

        num = 1 + x   
        df = 1 + x

        name = 'list' + str(num)
        name = [birthRate, Occupation, lifeSpan]

        empty_list.append(name)


    df = pd.DataFrame(empty_list, columns =['Birth Rate', 'Occupation', 'Life Span'])
    
    df.to_csv("/home/aaron/file_pop.csv")

    return(df)
    return(entered_num)

first_population(999)

df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

df1.info(verbose=True)

a = df['Occupation'].str.split('|', expand=True).stack().value_counts()

def plot_occupation(a):

    import matplotlib.pyplot as plt


    sales_by_type = a["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')

#     for index_label, row_series in a.iterrows():
#     # For each row update the 'Bonus' value to it's double
#         a.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
        
plot_occupation(a)

#print(type(a))

#df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 3 columns):
# Birth Rate    999 non-null int64
# Occupation    999 non-null object
# Life Span     999 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 23.5+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2958f7969093> in <module>
#      57 #         a.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
#      58
# ---> 59 plot_occupation(a)
#      60
#      61 #print(type(a))
#
# <ipython-input-13-2958f7969093> in plot_occupation(a)
#      46
#      47
# ---> 48     sales_by_type = a["Occupation"].value_counts()
#      49     sales_by_type.sort_values().plot(kind='barh')
#      50
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupation'

# %%
plot_occupation(a)

print (a)

df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-195fa8c80ee7> in <module>
# ----> 1 plot_occupation(a)
#       2
#       3 print (a)
#       4
#       5 df1
#
# <ipython-input-13-2958f7969093> in plot_occupation(a)
#      46
#      47
# ---> 48     sales_by_type = a["Occupation"].value_counts()
#      49     sales_by_type.sort_values().plot(kind='barh')
#      50
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupation'

# %% [markdown]
# <h3>Get dataframe and randomly select amount out of dataframe, reduce it <h3>

# %%
#print(entered_num)

df2 = df1.sample(frac = 0.2)

# %%
import matplotlib.pyplot as plt


sales_by_type = df2["Occupation"].value_counts()
sales_by_type.sort_values().plot(kind='barh')

plt.title('')
plt.ylabel('Occupation')
plt.xlabel('Amount of Population')

df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fab0dfe7668> in <module>
#       2
#       3
# ----> 4 sales_by_type = df2["Occupation"].value_counts()
#       5 sales_by_type.sort_values().plot(kind='barh')
#       6
#
# NameError: name 'df2' is not defined

# %% [markdown]
# <h3>Get Life span and modify its numbers by /2 <h3>

# %%
for index_label, row_series in df1.iterrows():

   # For each row update the 'Bonus' value to it's double
   df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
    
df1
# Out:
#      Birth Rate    Occupation  Life Span
# 0             3    GovWarlord         31
# 1             4  Manual Labor         34
# 2             2  Manual Labor         15
# 3             1  Agricultural         27
# 4             3          Tech         28
# ..          ...           ...        ...
# 994           3   Medical Aid         36
# 995           1       Militia         12
# 996           2       Militia         27
# 997           2  Manual Labor         41
# 998           2    GovWarlord         44
#
# [999 rows x 3 columns]

# %%
import numpy as np

df['elderly'] = np.where(df['Life Span']>=50, 'yes', 'no')

df
# Out:
#      Unnamed: 0  Birth Rate    Occupation  Life Span elderly
# 0             0           1    GovWarlord         87     yes
# 1             1           3          Tech         90     yes
# 2             2           2  Manual Labor         76     yes
# 3             3           3          Tech         90     yes
# 4             4           3    GovWarlord         21      no
# ..          ...         ...           ...        ...     ...
# 994         994           4  Manual Labor         30      no
# 995         995           4  Manual Labor         61     yes
# 996         996           3  Agricultural         98     yes
# 997         997           1   Medical Aid         46      no
# 998         998           3  Agricultural         76     yes
#
# [999 rows x 5 columns]

# %%
df3 = df2[df2.Occupation.str.contains('Militia',case=False)]

df3
# Out:
#      Birth Rate Occupation  Life Span
# 290           3    Militia         10
# 189           3    Militia         10
# 91            1    Militia         10
# 523           1    Militia         10
# 75            1    Militia         10
# ..          ...        ...        ...
# 498           2    Militia         10
# 739           4    Militia         10
# 68            3    Militia         10
# 668           1    Militia         10
# 151           1    Militia         10
#
# [85 rows x 3 columns]

# %% [markdown]
# <h3>Boolean to return a true or false depending on condition if records are present<h3>

# %%
# def militia_by2():
    
#     df1.bool()
    
#     if df1[df1['Occupation'] | 'Militia']:
#         for index_label, row_series in df1.iterrows():
#         # For each row update the 'Bonus' value to it's double
#             df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
            
            
# militia_by2()
militia = df1['Occupation'] == "Militia"

if militia.any() == True:
    print("yes")
    
else:
    print("no")
# Out:
# yes

# %% [markdown]
# <h3>Drop records based on a condition<h3>

# %%
dfdrop = df1.drop(df1[df1.Occupation == 'Militia'].index)

# %% [markdown]
# <h3>!!!!!!!!!!!!!!!!!!!!DEV AREA BELOW!!!!!!!!!!!!!!!!!!!!<h3>

# %%
for index_label, row_series in df1.iterrows():

   # For each row update the 'Bonus' value to it's double
   df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
    
df1

# %%
dfdrop = df1.drop(df1[df1.Occupation == 'Militia'].index)

# %%
dfdrop
# Out:
#      Birth Rate    Occupation  Life Span
# 1             3          Tech         96
# 2             1  Manual Labor         57
# 3             3    GovWarlord         60
# 4             1  Agricultural         64
# 5             4  Agricultural         72
# ..          ...           ...        ...
# 994           1  Agricultural         36
# 995           3  Agricultural         20
# 996           3          Tech         86
# 997           4  Manual Labor         24
# 998           4          Tech         81
#
# [837 rows x 3 columns]

# %%
import matplotlib.pyplot as plt


sales_by_type = dfdrop["Occupation"].value_counts()
sales_by_type.sort_values().plot(kind='barh')

plt.title('')
plt.ylabel('Occupation')
plt.xlabel('Amount of Population')

dfdrop
# Out:
#      Birth Rate    Occupation  Life Span
# 1             3          Tech         96
# 2             1  Manual Labor         57
# 3             3    GovWarlord         60
# 4             1  Agricultural         64
# 5             4  Agricultural         72
# ..          ...           ...        ...
# 994           1  Agricultural         36
# 995           3  Agricultural         20
# 996           3          Tech         86
# 997           4  Manual Labor         24
# 998           4          Tech         81
#
# [837 rows x 3 columns]
