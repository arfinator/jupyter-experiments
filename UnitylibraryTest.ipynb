# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *
from utils import *
import matplotlib.pyplot as plt

first_population(999)
# Out:
#      Birth Rate    Occupation  Life Span
# 0             4  Agricultural         81
# 1             2          Tech         52
# 2             3    GovWarlord         65
# 3             3  Manual Labor         97
# 4             2    GovWarlord         74
# ..          ...           ...        ...
# 994           2   Medical Aid         94
# 995           3          Tech         48
# 996           4          Tech         64
# 997           1          Tech         89
# 998           3          Tech         73
#
# [999 rows x 3 columns]

# %%
df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

#df.info(verbose=True)

# %%
df2 = df1.sample(frac = 0.2)

# %%
chart_it(df2)

# %%
chart_it(df2)

# %%
#df3 = df2['Tech'].sample(n=3, random_state=1)

#df1 = df[df.Occupation == "GovWarlord"].sample(frac = 0.2, replace=True)

df3
# Out:
#      Birth Rate    Occupation  Life Span
# 336           1          Tech         50
# 451           4  Agricultural         30
# 492           3          Tech         80
# 578           4       Militia         49
# 412           3       Militia         26
# ..          ...           ...        ...
# 947           3  Manual Labor         30
# 902           1   Medical Aid         93
# 994           2          Tech         40
# 875           2  Manual Labor         18
# 654           2       Militia         64
#
# [155 rows x 3 columns]

# %%
df2.drop( df2[ df2['Occupation'] == 'GovtWarlord' ].index , inplace=True)

# Delete these row indexes from dataFrame
#dfObj.drop(indexNames , inplace=True)

df2

# %%
df2[(df2['Occupation']=='GovWarlord')].index
# Out:
# Int64Index([944, 270, 665, 371,  21, 794, 367, 497, 144,   3, 890, 894, 545,
#             580, 938, 933, 638, 149, 370, 278, 622, 932, 363, 334, 701, 792,
#             556, 100, 402, 108, 136, 400, 462],
#            dtype='int64')

# %%
indexNames = df2[df2['Occupation']=='GovWarlord'].index

# %%
dfdrop = df2.drop(df2[df2['Occupation'] =='GovWarlord'].sample(frac=.8).index)

# %%
dfdrop
# Out:
#      Birth Rate    Occupation  Life Span
# 648           4   Medical Aid         79
# 744           4       Militia         48
# 727           3  Manual Labor         69
# 724           4       Militia         42
# 32            3          Tech         53
# ..          ...           ...        ...
# 955           2  Manual Labor         29
# 881           3   Medical Aid         18
# 63            2          Tech         51
# 446           4  Manual Labor         49
# 981           2          Tech         22
#
# [168 rows x 3 columns]

# %%
chart_it(dfdrop)

# %%
print(indexNames)
# Out:
# Int64Index([944, 270, 665, 371,  21, 794, 367, 497, 144,   3, 890, 894, 545,
#             580, 938, 933, 638, 149, 370, 278, 622, 932, 363, 334, 701, 792,
#             556, 100, 402, 108, 136, 400, 462],
#            dtype='int64')

# %%
df2.drop(indexNames, inplace=True)

# %%
type(droppeddf)
# Out:
# NoneType

# %%
type(df4)
# Out:
# NoneType

# %%
df2[(df2['Occupation']=='GovWarlord')].sample(n=50, replace=True)
# Out:
#      Birth Rate  Occupation  Life Span
# 222           4  GovWarlord         37
# 910           3  GovWarlord         58
# 997           4  GovWarlord         89
# 181           3  GovWarlord         68
# 665           4  GovWarlord         98
# 278           1  GovWarlord         50
# 997           4  GovWarlord         89
# 89            1  GovWarlord         46
# 111           1  GovWarlord         41
# 89            1  GovWarlord         46
# 518           1  GovWarlord         50
# 200           1  GovWarlord         67
# 200           1  GovWarlord         67
# 278           1  GovWarlord         50
# 869           3  GovWarlord         27
# 222           4  GovWarlord         37
# 542           1  GovWarlord         62
# 683           3  GovWarlord         92
# 132           3  GovWarlord         28
# 200           1  GovWarlord         67
# 222           4  GovWarlord         37
# 136           3  GovWarlord         95
# 508           4  GovWarlord         90
# ...

# %%
df2.shape
# Out:
# (200, 3)

# %%
to_remove = np.random.choice(df2[df2['Occupation']=='GovWarlord'].index,size=1068,replace=True)

df3 = df2.drop(to_remove)

# %%
# a = df2['Occupation'].str.split('|', expand=True).stack().value_counts()
# print (a)
# print(type(a))

df3
# Out:
#      Birth Rate    Occupation  Life Span
# 336           1          Tech         50
# 451           4  Agricultural         30
# 492           3          Tech         80
# 578           4       Militia         49
# 412           3       Militia         26
# ..          ...           ...        ...
# 947           3  Manual Labor         30
# 902           1   Medical Aid         93
# 994           2          Tech         40
# 875           2  Manual Labor         18
# 654           2       Militia         64
#
# [155 rows x 3 columns]
