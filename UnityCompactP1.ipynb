# %% [markdown]
# <h3>Generate first population and visualize<h3>

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *






def first_population(entered_num):

    empty_list = []

    for x in range(entered_num):


        lifeSpan = randrange(18,99)
        birthRate = randint(1, 4)
        Occupation = choice(['Manual Labor', 'Militia', 'Medical Aid', 'Agricultural', 'GovWarlord', 'Tech'])

        num = 1 + x   
        df = 1 + x

        name = 'list' + str(num)
        name = [birthRate, Occupation, lifeSpan]

        empty_list.append(name)


    df = pd.DataFrame(empty_list, columns =['Birth Rate', 'Occupation', 'Life Span'])
    
    df.to_csv("/home/aaron/file_pop.csv")

    return(df)
    return(entered_num)

first_population(999)

df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

df1.info(verbose=True)

#a = df['Occupation'].str.split('|', expand=True).stack().value_counts()


#def plot_occupation(df1):

    import matplotlib.pyplot as plt


    sales_by_type = df1["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')

    for index_label, row_series in df1.iterrows():
    # For each row update the 'Bonus' value to it's double
        df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2


        
        
plot_occupation(df1)

print (a)

df1
#print(type(a))

#df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 3 columns):
# Birth Rate    999 non-null int64
# Occupation    999 non-null object
# Life Span     999 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 23.5+ KB
# GovWarlord      191
# Agricultural    175
# Tech            169
# Medical Aid     163
# Manual Labor    156
# Militia         145
# dtype: int64
#      Birth Rate    Occupation  Life Span
# 0             4   Medical Aid         27
# 1             1  Agricultural         43
# 2             2       Militia         26
# 3             3   Medical Aid         21
# 4             4  Manual Labor         33
# ..          ...           ...        ...
# 994           2          Tech         16
# 995           1    GovWarlord         38
# 996           3  Agricultural         48
# 997           1       Militia         41
# 998           1  Agricultural         13
#
# [999 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *






def first_population(entered_num):

    empty_list = []

    for x in range(entered_num):


        lifeSpan = randrange(18,99)
        birthRate = randint(1, 4)
        Occupation = choice(['Manual Labor', 'Militia', 'Medical Aid', 'Agricultural', 'GovWarlord', 'Tech'])

        num = 1 + x   
        df = 1 + x

        name = 'list' + str(num)
        name = [birthRate, Occupation, lifeSpan]

        empty_list.append(name)


    df = pd.DataFrame(empty_list, columns =['Birth Rate', 'Occupation', 'Life Span'])
    
    df.to_csv("/home/aaron/file_pop.csv")

    return(df)
    return(entered_num)

first_population(999)

df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

df1.info(verbose=True)

#a = df['Occupation'].str.split('|', expand=True).stack().value_counts()


#def plot_occupation(df1):

    import matplotlib.pyplot as plt


    sales_by_type = df1["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')

    for index_label, row_series in df1.iterrows():
    # For each row update the 'Bonus' value to it's double
        df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2


        
        
plot_occupation(df1)

print (a)

df1
#print(type(a))

#df1

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *

def first_population(entered_num):

    empty_list = []

    for x in range(entered_num):


        lifeSpan = randrange(18,99)
        birthRate = randint(1, 4)
        Occupation = choice(['Manual Labor', 'Militia', 'Medical Aid', 'Agricultural', 'GovWarlord', 'Tech'])

        num = 1 + x
        df = 1 + x

        name = 'list' + str(num)
        name = [birthRate, Occupation, lifeSpan]

        empty_list.append(name)


    df = pd.DataFrame(empty_list, columns =['Birth Rate', 'Occupation', 'Life Span'])

    df.to_csv("/home/aaron/file_pop.csv")

    return(df)

def chart_it(df):
    
    import matplotlib.pyplot as plt
    
    sales_by_type = df["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')
    
    for index_label, row_series in df.iterrows():
    # For each row update the 'Bonus' value to it's double
        df.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
        
        df
        
first_population(999)

chart_it(df)

# %%
df1
# Out:
#      Birth Rate    Occupation  Life Span
# 0             3       Militia         44
# 1             1    GovWarlord         32
# 2             4   Medical Aid         22
# 3             2       Militia         27
# 4             1          Tech         15
# ..          ...           ...        ...
# 994           1   Medical Aid         16
# 995           4  Agricultural         43
# 996           1  Manual Labor         23
# 997           1   Medical Aid         41
# 998           4  Agricultural         38
#
# [999 rows x 3 columns]

# %% [markdown]
# <h3>Get dataframe and randomly select amount out of dataframe, reduce it <h3>

# %%
#print(entered_num)

df2 = df1.sample(n = 50)

# %%
df2 = df1.sample(frac = 0.45)

# %%
import matplotlib.pyplot as plt


sales_by_type = df2["Occupation"].value_counts()
sales_by_type.sort_values().plot(kind='barh')

plt.title('')
plt.ylabel('Occupation')
plt.xlabel('Amount of Population')

df2
# Out:
#      Birth Rate    Occupation  Life Span
# 438           3   Medical Aid         25
# 523           4  Agricultural         47
# 40            2   Medical Aid         27
# 238           3          Tech         24
# 167           2  Agricultural         38
# ..          ...           ...        ...
# 52            1   Medical Aid         38
# 882           3  Manual Labor         30
# 736           3    GovWarlord         27
# 847           3  Manual Labor         34
# 856           3    GovWarlord         45
#
# [450 rows x 3 columns]

# %% [markdown]
# <h3>Get Life span and modify its numbers by /2 <h3>

# %%
for index_label, row_series in df1.iterrows():
   # For each row update the 'Bonus' value to it's double
   df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
    
df1
# Out:
#      Birth Rate    Occupation  Life Span
# 0             4  Manual Labor         44
# 1             4    GovWarlord          9
# 2             4       Militia         22
# 3             4  Manual Labor         16
# 4             3          Tech         14
# ..          ...           ...        ...
# 994           1          Tech         47
# 995           3   Medical Aid         22
# 996           1          Tech         44
# 997           1   Medical Aid         27
# 998           4   Medical Aid         43
#
# [999 rows x 3 columns]

# %%
import numpy as np

df['elderly'] = np.where(df['Life Span']>=50, 'yes', 'no')

df
# Out:
#      Unnamed: 0  Birth Rate   Occupation  Life Span elderly
# 0             0           4  Medical Aid         28      no
# 1             1           1   GovWarlord         63     yes
# 2             2           4      Militia         68     yes
# 3             3           1      Militia         67     yes
# 4             4           3         Tech         44      no
# ..          ...         ...          ...        ...     ...
# 994         994           4         Tech         95     yes
# 995         995           1         Tech         64     yes
# 996         996           1   GovWarlord         72     yes
# 997         997           4   GovWarlord         74     yes
# 998         998           2   GovWarlord         30      no
#
# [999 rows x 5 columns]

# %%
for index_label, row_series in df1.iterrows():
   # For each row update the 'Bonus' value to it's double
   df1.at[index_label , 'Life Span'] = row_series['Life Span'] / 2
    
df1
# Out:
#      Birth Rate    Occupation  Life Span
# 0             3          Tech         20
# 1             3          Tech         11
# 2             1          Tech          5
# 3             4  Manual Labor         10
# 4             1    GovWarlord         23
# ..          ...           ...        ...
# 994           4          Tech          7
# 995           2          Tech         17
# 996           2  Manual Labor         17
# 997           3    GovWarlord         16
# 998           4          Tech         16
#
# [999 rows x 3 columns]

# %%
def plot_occupation():

    import matplotlib.pyplot as plt


    sales_by_type = df1["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')
    
    
plot_occupation()

# %%
# List of Tuples
salaries = [(11, 5, 70000, 1000) ,
           (12, 7, 72200, 1100) ,
           (13, 11, 84999, 1000)
           ]
 
# Create a DataFrame object
salaryDfObj = pd.DataFrame(salaries, columns=['ID', 'Experience' , 'Salary', 'Bonus'])

salaryDfObj
# Out:
#    ID  Experience  Salary  Bonus
# 0  11           5   70000   1000
# 1  12           7   72200   1100
# 2  13          11   84999   1000

# %%
for index_label, row_series in salaryDfObj.iterrows():
   # For each row update the 'Bonus' value to it's double
   salaryDfObj.at[index_label , 'Bonus'] = row_series['Bonus'] / 2
    
salaryDfObj
# Out:
#    ID  Experience  Salary  Bonus
# 0  11           5   70000    250
# 1  12           7   72200    275
# 2  13          11   84999    250

# %%
def plot_occupation2():

    import matplotlib.pyplot as plt


    sales_by_type = salaryDfObj["Occupation"].value_counts()
    sales_by_type.sort_values().plot(kind='barh')

    plt.title('')
    plt.ylabel('Occupation')
    plt.xlabel('Amount of Population')
    
    
plot_occupation2()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupation'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-41205e1b38d2> in <module>
#      12
#      13
# ---> 14 plot_occupation2()
#
# <ipython-input-16-41205e1b38d2> in plot_occupation2()
#       4
#       5
# ----> 6     sales_by_type = salaryDfObj["Occupation"].value_counts()
#       7     sales_by_type.sort_values().plot(kind='barh')
#       8
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupation'
