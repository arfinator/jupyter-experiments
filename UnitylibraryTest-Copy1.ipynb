# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from random import *
from utils import *
import matplotlib.pyplot as plt

first_population(999)
# Out:
#      Birth Rate    Occupation  Life Span
# 0             1   Medical Aid         50
# 1             3  Manual Labor         53
# 2             2       Militia         43
# 3             2  Manual Labor         79
# 4             3          Tech         49
# ..          ...           ...        ...
# 994           2          Tech         40
# 995           4       Militia         31
# 996           4   Medical Aid         63
# 997           1  Agricultural         23
# 998           1       Militia         72
#
# [999 rows x 3 columns]

# %%
df = pd.read_csv('/home/aaron/file_pop.csv')

df1 = df.drop(columns = ['Unnamed: 0'])

#df.info(verbose=True)

# %%
df2 = df1.sample(frac = 0.2)

# %%
chart_it(df2)

# %%
chart_it(df3)

# %%
#df3 = df2['Tech'].sample(n=3, random_state=1)

#df1 = df[df.Occupation == "GovWarlord"].sample(frac = 0.2, replace=True)

df3
# Out:
#      Birth Rate    Occupation  Life Span
# 336           1          Tech         50
# 451           4  Agricultural         30
# 492           3          Tech         80
# 578           4       Militia         49
# 412           3       Militia         26
# ..          ...           ...        ...
# 947           3  Manual Labor         30
# 902           1   Medical Aid         93
# 994           2          Tech         40
# 875           2  Manual Labor         18
# 654           2       Militia         64
#
# [155 rows x 3 columns]

# %%
# Get names of indexes for which column Age has value 30
indexNames = df[ df['Occupation'] == 'GovWarlord'].index

df1 = df[df.Occupation == "GovWarlord"].sample(frac = 0.2, replace=True)

# Delete these row indexes from dataFrame
dfObj.drop(indexNames , inplace=True)

# %%
to_remove = np.random.choice(df2[df2['Occupation']=='GovWarlord'].index,size=1068,replace=True)

df3 = df2.drop(to_remove)

# %%
# a = df2['Occupation'].str.split('|', expand=True).stack().value_counts()
# print (a)
# print(type(a))

df3
# Out:
#      Birth Rate    Occupation  Life Span
# 336           1          Tech         50
# 451           4  Agricultural         30
# 492           3          Tech         80
# 578           4       Militia         49
# 412           3       Militia         26
# ..          ...           ...        ...
# 947           3  Manual Labor         30
# 902           1   Medical Aid         93
# 994           2          Tech         40
# 875           2  Manual Labor         18
# 654           2       Militia         64
#
# [155 rows x 3 columns]
