# %%
import pyodbc
import numpy
import pandas

host = "192.168.1.16"
port = 31010
uid = 'aarfon'
pwd = 'Fuckgod666'
driver = "Dremio ODBC Driver 64-bit"

cnxn = pyodbc.connect("Driver={};ConnectionType=Direct;HOST={};PORT={};AuthenticationType=Plain;UID={};PWD={}".format(driver, host,port,uid,pwd),autocommit=True)

# %%
sql = '''SELECT * FROM arf.stores'''

# %%
dataframe = pandas.read_sql(sql,cnxn)

# %%
dataframe
# Out:
#                                     id    chain   banner store_number  \
# 0     a172795bdb99441f8a53de6d2becd81c  Walmart  Walmart         2070
# 1     d79869953b684ab3a11d1cc9f1c7b353  Walmart  Walmart         2071
# 2     803473b7ad1742568d1154c4e79a7af5  Walmart  Walmart         2074
# 3     c38f45a3bdc948928e453451535cd604  Walmart  Walmart         2188
# 4     4f8a4a08b406407fbf3eb2eeeddf3021  Walmart  Walmart         2710
# ...                                ...      ...      ...          ...
# 7247  637c0ad9e12d488abb4e9b89be8585d4   Kroger  Smith's     70600182
# 7248  5e16ad94b4ae4726bf03a59e15160e40   Kroger  Smith's     70600183
# 7249  2689682a772d44e0b55a955c1a278b37   Kroger  Smith's     70600184
# 7250  6b9825e47d97421cb4aeaf44e9104464   Kroger  Smith's     70600185
# 7251  80caa213edfb42e9876318df2d0230f4   Kroger  Smith's     70600187
#
#                           address          city state postal_code country  \
# 0                       3101 A St     Anchorage    AK       99503
# 1             8900 Old Seward Hwy     Anchorage    AK       99515
# 2     1350 S Seward Meridian Pkwy       Wasilla    AK       99654
# 3            18600 Eagle River Rd   Eagle River    AK       99577
# 4                4230 Don King Rd     Ketchikan    AK       99901
# ...                           ...           ...   ...         ...     ...
# 7247           2531 Foothill Blvd  Rock Springs    WY       82901      US
# 7248               1200 W Main St      Riverton    WY       82501      US
# 7249                1425 S Hwy 89       Jackson    WY       83001      US
# 7250                  2405 Cy Ave        Casper    WY       82604      US
# 7251               905 Bridger Dr   Green River    WY       82935      US
#
#         latitude     longitude active     updated
# 0      61.192213   -149.879549   true  2018-06-13
# 1      61.140195   -149.869863   true  2018-06-13
# 2      61.568719   -149.365105   true  2018-06-13
# 3      61.309037   -149.535439   true  2018-06-13
# 4      55.375474   -131.720399   true  2018-06-13
# ...          ...           ...    ...         ...
# 7247   41.582958   -109.260703   true  2018-08-29
# 7248  43.0255124  -108.4090145   true  2018-08-29
# 7249  43.4587962  -110.7956985   true  2018-08-29
# 7250  42.8279296  -106.3530667   true  2018-08-29
# 7251  41.5044202  -109.4582419   true  2018-08-29
#
# [7252 rows x 13 columns]
